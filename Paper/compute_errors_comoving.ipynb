# %% [markdown]
# In this notebook, we compute LTE intensities (and save them in .npy files). Then another notebook may postprocess them in order to create plots. TODO: explicitly add functionality to compute the reduced models in another notebook (instead of depending on some documentation notebook). TODO: add version number of magritte used/usable to run this notebook.

# %%
import magritte.core     as magritte   # Core functionality
import magritte.plot     as plot       # Plotting
import magritte.tools    as tools      # Save fits
import numpy as np
import os
import time                                            # For timing

from astropy import units              # Unit conversions

# %% [markdown]
# Define a working directory (you will have to change this). We assume here that the scripts of the this example have already been executed and go back to that working directory.

# %%
wdir = "/STER/thomasc/Magritte_comoving/Magritte-examples/Phantom_3D_fullNLTE/"

# %% [markdown]
# Define file names.

# %%
model_file_rec = os.path.join(wdir, 'wind_red_rec.hdf5')   # reduced 3D Phantom Magritte model
model_file_original = os.path.join(wdir, 'model_Phantom_3D_for_comoving.hdf5')
   # original 3D Phantom Magritte model
J_file_feaut = os.path.join(wdir, 'J_feautrier.npy')
J_file_comoving = os.path.join(wdir, 'J_comoving.npy')
J_file_comapp = os.path.join(wdir, 'J_comapp.npy')
J_file_shortchar = os.path.join(wdir, 'J_shortchar.npy')

J_file_original_comoving = os.path.join(wdir, 'J_original_comoving.npy')
J_file_original_feautrier = os.path.join(wdir, 'J_original_feautrier.npy')
J_file_original_comapp = os.path.join(wdir, 'J_original_comapp.npy')

NLTE_J_file_feaut = os.path.join(wdir, 'NLTE_J_rec.npy')
NLTE_J_file_comoving = os.path.join(wdir, 'NLTE_J_comoving.npy')
NLTE_J_file_comoving_approx = os.path.join(wdir, 'NLTE_J_comoving_approx.npy')

# model_file_rec_feautrier_save = os.path.join(wdir, 'wind_rec_feautrier_save.hdf5')   # reduced 3D Phantom Magritte model
# model_file_rec_comoving_save = os.path.join(wdir, 'wind_rec_comoving_save.hdf5')   # reduced 3D Phantom Magritte model
# model_file_rec_comapp_save = os.path.join(wdir, 'wind_rec_comapp_save.hdf5')   # reduced 3D Phantom Magritte model

model_file_original_feautrier_save = os.path.join(wdir, 'model_Phantom_3D_feautrier_save.hdf5')   # original 3D Phantom Magritte model
model_file_original_comoving_save = os.path.join(wdir, 'model_Phantom_3D_comoving_save.hdf5')   # original 3D Phantom Magritte model
model_file_original_comapp_save = os.path.join(wdir, 'model_Phantom_3D_comapp_save.hdf5')   # original 3D Phantom Magritte model

# %% [markdown]
# Load all models

# %%
model_original = magritte.Model(model_file_original)
model_rec = magritte.Model(model_file_rec)
# Out:
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /STER/thomasc/Magritte_comoving/Magritte-examples/Phantom_3D_fullNLTE/model_Phantom_3D_for_comoving.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym CO
# nlev = 41
# nrad = 40
# Reading collisionPartner...
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 885501
#   nrays      = 48
#   nboundary  = 1200
#   nfreqs     = 840
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 40
#   nquads     = 21
# -------------------------------------------
#
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /STER/thomasc/Magritte_comoving/Magritte-examples/Phantom_3D_fullNLTE/wind_red_rec.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 1
# read sym CO
# nlev = 41
# nrad = 40
# Reading collisionPartner...
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 52258
#   nrays      = 48
#   nboundary  = 1202
#   nfreqs     = 840
#   nspecs     = 5
#   nlspecs    = 1
#   nlines     = 40
#   nquads     = 21
# -------------------------------------------

# %%
model_rec.compute_spectral_discretisation ()
model_rec.compute_inverse_line_widths     ()
model_rec.compute_LTE_level_populations   ()

model_original.compute_spectral_discretisation ()
model_original.compute_inverse_line_widths     ()
model_original.compute_LTE_level_populations   ()
# Out:
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# 0

# %% [markdown]
# Initialize all models.

# %% [markdown]
# ## Computing mean line intensities

# %% [markdown]
# Use sparse feautrier solver to compute radiation field

# %%
start = time.time()
model_rec.compute_radiation_field_feautrier_order_2_sparse()
end = time.time()
print("Feautrier computation time: ", end - start)
# Out:
# Computing radiation field...
# Feautrier computation time:  51.497309923172
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23

# %% [markdown]
# Save in .npy file.

# %%
np.save(J_file_feaut, np.array(model_rec.lines.lineProducingSpecies[0].J))

# %%
start = time.time()
model_rec.compute_radiation_field_comoving()
end = time.time()
print("Comoving computation time: ", end - start)
np.save(J_file_comoving, np.array(model_rec.lines.lineProducingSpecies[0].J))
# Out:
# Comoving computation time:  59.281944036483765
# Computing radiation field...
# rr: 0 size points_to_trace_ray_through: 5325
# rr: 1 size points_to_trace_ray_through: 5820
# rr: 2 size points_to_trace_ray_through: 6499
# rr: 3 size points_to_trace_ray_through: 6540
# rr: 4 size points_to_trace_ray_through: 5725
# rr: 5 size points_to_trace_ray_through: 6349
# rr: 6 size points_to_trace_ray_through: 6328
# rr: 7 size points_to_trace_ray_through: 5779
# rr: 8 size points_to_trace_ray_through: 6435
# rr: 9 size points_to_trace_ray_through: 6999
# rr: 10 size points_to_trace_ray_through: 7051
# rr: 11 size points_to_trace_ray_through: 6365
# rr: 12 size points_to_trace_ray_through: 5831
# rr: 13 size points_to_trace_ray_through: 6612
# rr: 14 size points_to_trace_ray_through: 7062
# rr: 15 size points_to_trace_ray_through: 6627
# rr: 16 size points_to_trace_ray_through: 5512
# rr: 17 size points_to_trace_ray_through: 6972
# rr: 18 size points_to_trace_ray_through: 6637
# rr: 19 size points_to_trace_ray_through: 6974
# rr: 20 size points_to_trace_ray_through: 6117
# rr: 21 size points_to_trace_ray_through: 7066
# rr: 22 size points_to_trace_ray_through: 7029
# rr: 23 size points_to_trace_ray_through: 6126
# number of origin point/ray idx combinations with only a single data point saved: 33147
# total number of rays: 153780
# hnrays: 24

# %%
start = time.time()
model_rec.compute_radiation_field_comoving_local_approx()
end = time.time()
print("Comoving local approx computation time: ", end - start)
np.save(J_file_comapp, np.array(model_rec.lines.lineProducingSpecies[0].J))
# Out:
# Comoving local approx computation time:  20.291401386260986
# Computing radiation field...
# setup length: 289
# setup width: 840
# rr: 0 size points_to_trace_ray_through: 5325
# rr: 1 size points_to_trace_ray_through: 5820
# rr: 2 size points_to_trace_ray_through: 6499
# rr: 3 size points_to_trace_ray_through: 6540
# rr: 4 size points_to_trace_ray_through: 5725
# rr: 5 size points_to_trace_ray_through: 6349
# rr: 6 size points_to_trace_ray_through: 6328
# rr: 7 size points_to_trace_ray_through: 5779
# rr: 8 size points_to_trace_ray_through: 6435
# rr: 9 size points_to_trace_ray_through: 6999
# rr: 10 size points_to_trace_ray_through: 7051
# rr: 11 size points_to_trace_ray_through: 6365
# rr: 12 size points_to_trace_ray_through: 5831
# rr: 13 size points_to_trace_ray_through: 6612
# rr: 14 size points_to_trace_ray_through: 7062
# rr: 15 size points_to_trace_ray_through: 6627
# rr: 16 size points_to_trace_ray_through: 5512
# rr: 17 size points_to_trace_ray_through: 6972
# rr: 18 size points_to_trace_ray_through: 6637
# rr: 19 size points_to_trace_ray_through: 6974
# rr: 20 size points_to_trace_ray_through: 6117
# rr: 21 size points_to_trace_ray_through: 7066
# rr: 22 size points_to_trace_ray_through: 7029
# rr: 23 size points_to_trace_ray_through: 6126
# number of origin point/ray idx combinations with only a single data point saved: 33147
# total number of rays: 153780
# hnrays: 24

# %% [markdown]
# And finally compare with long characteristics solver

# %%
# Is not sparse variant, so does not fit in memory
# start = time.time()
# model_rec.compute_LTE_level_populations()
# model_rec.compute_radiation_field_shortchar_order_0()
# #non sparse solver has slightly more cumbersome access to J
# print(np.array(model_rec.radiation.J).shape)
# nlines = model_rec.parameters.nlines()
# npoints = model_rec.parameters.npoints()
# weights = np.tile(np.array(model_rec.lines.lineProducingSpecies[0].quadrature.weights),nlines)
# print(weights)
# weighted_J = weights[np.newaxis, :]*np.array(model_rec.radiation.J)
# computed_J = weighted_J.reshape(npoints, nlines, -1).sum(axis=2)
# # computed_J = np.sum(np.array(model_rec.radiation.J)*weights[np.newaxis, :], axis=1)
# np.save(J_file_shortchar, computed_J)
# #also the save format is slightly different, as only a single axis is required for this single line
# end = time.time()
# print("Shortchar computation time: ", end - start)

# %% [markdown]
# The next computations are using the original model, so can take quite some time.

# %%
start = time.time()
model_original.compute_radiation_field_comoving()
end = time.time()
print("Comoving computation time on original: ", end - start)
np.save(J_file_original_comoving, np.array(model_original.lines.lineProducingSpecies[0].J))
# Out:
# Comoving computation time on original:  815.5481026172638
# Computing radiation field...
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24

# %%
start = time.time()
model_original.compute_radiation_field_comoving_local_approx()
end = time.time()
print("Comoving computation time on original: ", end - start)
np.save(J_file_original_comapp, np.array(model_original.lines.lineProducingSpecies[0].J))
# Out:
# Comoving computation time on original:  347.38679361343384
# Computing radiation field...
# setup length: 833
# setup width: 840
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24

# %%
start = time.time()
model_original.compute_radiation_field_feautrier_order_2_sparse()
end = time.time()
print("Comoving computation time on original: ", end - start)
np.save(J_file_original_feautrier, np.array(model_original.lines.lineProducingSpecies[0].J))
# Out:
# Computing radiation field...
# Comoving computation time on original:  1937.2516403198242
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23

# %% [markdown]
# ## NLTE computations

# %% [markdown]
# The goal of the new type of solvers is to compute NLTE a bit faster, thus we will compute NLTE on the original grid; and compare the speedups. Note: we will not be using Ng-acceleration, as this will complicate the analysis a lot...

# %%
model_original.compute_LTE_level_populations()
start = time.time()
model_original.compute_level_populations_comoving(False, 5)#Without ng-acceleration, because it becomes a bit cumbersome to compare if I also include it
end = time.time()
print("NLTE Comoving computation time on reduced: ", end - start)
np.save(NLTE_J_file_comoving, np.array(model_original.lines.lineProducingSpecies[0].J))
model_original.write(model_file_original_comoving_save)
# Out:
# Computing LTE level populations...
# using ng acceleration? 0
# Starting iteration 1
# Computing the radiation field...
# Computing radiation field...
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 siNLTE Comoving computation time on reduced:  4858.832401037216
# ze points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24
# Tot | Compute Radiation Field : 1094.686196 seconds
# Tot | Compute Statistical Equilibrium : 6.285615 seconds
# Already 0.473925 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24
# Tot | Compute Radiation Field : 2172.130479 seconds
# Tot | Compute Statistical Equilibrium : 10.069724 seconds
# Already 1.04012 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24
# Tot | Compute Radiation Field : 3091.221360 seconds
# Tot | Compute Statistical Equilibrium : 13.449503 seconds
# Already 35.989 % converged!
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24
# Tot | Compute Radiation Field : 4035.776682 seconds
# Tot | Compute Statistical Equilibrium : 16.717657 seconds
# Already 98.6712 % converged!
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24
# Tot | Compute Radiation Field : 4838.760348 seconds
# Tot | Compute Statistical Equilibrium : 20.070427 seconds
# Already 99.9982 % converged!
# Converged after 5 iterations
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 2
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# --- colpoar = 1
# Writing collisionPartner...
# (l, c) = 0, 1
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...

# %% [markdown]
# Also compare with comoving approx version

# %%
model_original.compute_LTE_level_populations   ()
start = time.time()
model_original.compute_level_populations_comoving_local_approx(False, 5)#Without ng-acceleration, because it becomes a bit cumbersome to compare if I also include it
end = time.time()
print("NLTE Comoving computation time on reduced: ", end - start)
np.save(NLTE_J_file_comoving_approx, np.array(model_original.lines.lineProducingSpecies[0].J))
model_original.write(model_file_original_comapp_save)
# Out:
# Computing LTE level populations...
# NLTE Comoving computation time on reduced:  1864.5147330760956
# using ng acceleration? 0
# Starting iteration 1
# Computing the radiation field...
# Computing radiation field...
# setup length: 833
# setup width: 840
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24
# Tot | Compute Radiation Field : 364.921550 seconds
# Tot | Compute Statistical Equilibrium : 3.382819 seconds
# Already 0.473955 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# setup length: 833
# setup width: 840
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24
# Tot | Compute Radiation Field : 735.965746 seconds
# Tot | Compute Statistical Equilibrium : 8.544351 seconds
# Already 1.07439 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# setup length: 833
# setup width: 840
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24
# Tot | Compute Radiation Field : 1105.905516 seconds
# Tot | Compute Statistical Equilibrium : 12.029103 seconds
# Already 37.7852 % converged!
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# setup length: 833
# setup width: 840
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24
# Tot | Compute Radiation Field : 1474.166910 seconds
# Tot | Compute Statistical Equilibrium : 15.532474 seconds
# Already 98.9058 % converged!
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# setup length: 833
# setup width: 840
# rr: 0 size points_to_trace_ray_through: 32025
# rr: 1 size points_to_trace_ray_through: 31928
# rr: 2 size points_to_trace_ray_through: 38642
# rr: 3 size points_to_trace_ray_through: 38774
# rr: 4 size points_to_trace_ray_through: 32677
# rr: 5 size points_to_trace_ray_through: 37395
# rr: 6 size points_to_trace_ray_through: 37206
# rr: 7 size points_to_trace_ray_through: 32498
# rr: 8 size points_to_trace_ray_through: 37394
# rr: 9 size points_to_trace_ray_through: 44824
# rr: 10 size points_to_trace_ray_through: 45117
# rr: 11 size points_to_trace_ray_through: 37665
# rr: 12 size points_to_trace_ray_through: 33018
# rr: 13 size points_to_trace_ray_through: 38911
# rr: 14 size points_to_trace_ray_through: 43827
# rr: 15 size points_to_trace_ray_through: 38833
# rr: 16 size points_to_trace_ray_through: 32797
# rr: 17 size points_to_trace_ray_through: 42667
# rr: 18 size points_to_trace_ray_through: 48043
# rr: 19 size points_to_trace_ray_through: 42745
# rr: 20 size points_to_trace_ray_through: 36077
# rr: 21 size points_to_trace_ray_through: 45702
# rr: 22 size points_to_trace_ray_through: 45504
# rr: 23 size points_to_trace_ray_through: 36110
# number of origin point/ray idx combinations with only a single data point saved: 139389
# total number of rays: 930379
# hnrays: 24
# Tot | Compute Radiation Field : 1844.705679 seconds
# Tot | Compute Statistical Equilibrium : 19.806110 seconds
# Already 99.9987 % converged!
# Converged after 5 iterations
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 2
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# --- colpoar = 1
# Writing collisionPartner...
# (l, c) = 0, 1
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...

# %% [markdown]
# And evidently versus the baseline feautrier solver.

# %%
model_original.compute_LTE_level_populations   ()
start = time.time()
model_original.compute_level_populations_sparse(False, 5)
end = time.time()
print("NLTE feautrier computation time on reduced: ", end - start)
np.save(NLTE_J_file_feaut, np.array(model_original.lines.lineProducingSpecies[0].J))
model_original.write(model_file_original_feautrier_save)
# Out:
# Computing LTE level populations...
# NLTE feautrier computation time on reduced:  9713.087149143219
# using ng acceleration? 0
# Starting iteration 1
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 1939.861582 seconds
# Tot | Compute Statistical Equilibrium : 4.059253 seconds
# Already 0.473969 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 3886.449201 seconds
# Tot | Compute Statistical Equilibrium : 7.931791 seconds
# Already 1.12467 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 5828.898662 seconds
# Tot | Compute Statistical Equilibrium : 11.432587 seconds
# Already 38.6547 % converged!
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 7763.288657 seconds
# Tot | Compute Statistical Equilibrium : 15.302169 seconds
# Already 98.7932 % converged!
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 9693.846664 seconds
# Tot | Compute Statistical Equilibrium : 19.236978 seconds
# Already 99.9999 % converged!
# Converged after 5 iterations
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 2
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# --- colpoar = 1
# Writing collisionPartner...
# (l, c) = 0, 1
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
